# %% [markdown]
# ---
# # Tutorial Task: Sentiment-Based Quant Strategy
# ---

# %% [markdown]
# In this tutorial, you will design and implement a **quantitative trading strategy** that makes trading decisions based on **news sentiment** for a selected group of 3 stocks.

# %% [markdown]
# ## Objective
#
# Each day, over a 1-week historical period:
# - **Buy** (go long) the stock with the **most positive** news sentiment
# - **Sell** (go short) the stock with the **most negative** news sentiment
#
# You will:
# 1. Select your own **universe of 3 stocks** (e.g., AAPL, BRK-B, DNUT, MSFT, GOOGL, AMZN, TSLA).
# 2. Use the provided News API to retrieve articles for each stock.
# 3. Calculate the **average sentiment** for each stock daily using tools like `TextBlob`.
# 4. Track your portfolio’s value over time by simulating simple returns.
# 5. Plot your portfolio value and analyze strategy performance.
#
# ## Constraints
#
# - The News API is limited to **100 requests per day**. Avoid excessive API calls while developing by storing data or limiting requests.
# - You only trade **one long and one short position** per day.
# - Keep it simple: assume equal capital allocation to long and short trades.

# %% [markdown]
# ## Step 1:
# Import relevant libraries

# %%
# Data analysis
import pandas as pd
import numpy as np

# API call
import requests

# Sentiment analysis
from textblob import TextBlob

# Time arithmetic
from datetime import datetime, timedelta

# Plotting
import matplotlib.pyplot as plt

# Financial data
# !pip install --upgrade --force-reinstall yfinance
import yfinance as yf
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.60-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pandas>=1.3.0 (from yfinance)
#   Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting numpy>=1.16.5 (from yfinance)
#   Using cached numpy-2.2.5-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting requests>=2.31 (from yfinance)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Collecting platformdirs>=2.0.0 (from yfinance)
#   Using cached platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.18.1-cp313-cp313-macosx_10_13_universal2.whl
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.10.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Using cached protobuf-6.30.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.11.1->yfinance)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Using cached cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.7->yfinance)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=1.3.0->yfinance)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.3.0->yfinance)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->yfinance)
#   Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.31->yfinance)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->yfinance)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached yfinance-0.2.60-py2.py3-none-any.whl (117 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached curl_cffi-0.10.0-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Using cached frozendict-2.4.6-py313-none-any.whl (16 kB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Using cached numpy-2.2.5-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl (11.3 MB)
# Using cached platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Using cached protobuf-6.30.2-cp39-abi3-macosx_10_9_universal2.whl (417 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached cffi-1.17.1-cp313-cp313-macosx_11_0_arm64.whl (178 kB)
# Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl (199 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pytz, peewee, multitasking, websockets, urllib3, tzdata, typing-extensions, soupsieve, six, pycparser, protobuf, platformdirs, numpy, idna, frozendict, charset-normalizer, certifi, requests, python-dateutil, cffi, beautifulsoup4, pandas, curl_cffi, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: peewee
#     Found existing installation: peewee 3.18.1
#     Uninstalling peewee-3.18.1:
#       Successfully uninstalled peewee-3.18.1
#   Attempting uninstall: multitasking
#     Found existing installation: multitasking 0.0.11
#     Uninstalling multitasking-0.0.11:
#       Successfully uninstalled multitasking-0.0.11
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.7
#     Uninstalling soupsieve-2.7:
#       Successfully uninstalled soupsieve-2.7
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.22
#     Uninstalling pycparser-2.22:
#       Successfully uninstalled pycparser-2.22
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.30.2
#     Uninstalling protobuf-6.30.2:
#       Successfully uninstalled protobuf-6.30.2
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.8
#     Uninstalling platformdirs-4.3.8:
#       Successfully uninstalled platformdirs-4.3.8
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.4.6
#     Uninstalling frozendict-2.4.6:
#       Successfully uninstalled frozendict-2.4.6
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.2
#     Uninstalling charset-normalizer-3.4.2:
#       Successfully uninstalled charset-normalizer-3.4.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.4.26
#     Uninstalling certifi-2025.4.26:
#       Successfully uninstalled certifi-2025.4.26
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.4
#     Uninstalling beautifulsoup4-4.13.4:
#       Successfully uninstalled beautifulsoup4-4.13.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: curl_cffi
#     Found existing installation: curl_cffi 0.10.0
#     Uninstalling curl_cffi-0.10.0:
#       Successfully uninstalled curl_cffi-0.10.0
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.60
#     Uninstalling yfinance-0.2.60:
#       Successfully uninstalled yfinance-0.2.60
# Successfully installed beautifulsoup4-4.13.4 certifi-2025.4.26 cffi-1.17.1 charset-normalizer-3.4.2 curl_cffi-0.10.0 frozendict-2.4.6 idna-3.10 multitasking-0.0.11 numpy-2.2.5 pandas-2.2.3 peewee-3.18.1 platformdirs-4.3.8 protobuf-6.30.2 pycparser-2.22 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.3 six-1.17.0 soupsieve-2.7 typing-extensions-4.13.2 tzdata-2025.2 urllib3-2.4.0 websockets-15.0.1 yfinance-0.2.60
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Step 2:
# Configure your API
#
# https://newsapi.org/

# %%
API_KEY = "a08fc23ee4b047689fd0e79abc557120"
BASE_URL = "https://newsapi.org/v2/everything"

# %% [markdown]
# ## Step 3:
# Create a function to get news and calculate the sentiment

# %%
# We use TextBlob() to calculate sentiment:

# Show students how this works
print(TextBlob("This stock is amazing!").sentiment.polarity) # ~0.7-1 is a positive sentiment
print(TextBlob("This stock is okay").sentiment.polarity) # ~0.2 is a slightly positive sentiment
print(TextBlob("This stock is awful!").sentiment.polarity) # ~-0.8-1 is a negative sentiment
print(TextBlob("This is a stock").sentiment.polarity) # 0 is a neutral sentiment

# polarity ranges from -1 to 1
# Out:
# 0.7500000000000001
# 0.5
# -1.0
# 0.0

# %%
# We make a function to call the API and get the sentiment of a stock over a day

def get_sentiment(stock, date):
    from_date = date.strftime('%Y-%m-%d')
    to_date = (date + timedelta(days = 1)).strftime('%Y-%m-%d')

    params = {
        'q': stock,
        'from': from_date,
        'to': to_date,
        'sortBy': 'relevancy',
        'apiKey': API_KEY,
        'language': 'en',
        'pageSize': 5
    }

    # Call API with the relevant stock and dates
    response = requests.get(BASE_URL, params=params)
    data = response.json() # response in a .JSON format

    print(data)

    sentiments = []
    for article in data.get('articles', []):
        title = article.get('title', '')
        description = article.get('description', '')

        if not title and not description:
            continue #skip if both are missing
    
        text = f"{title} {description}"
        # Get sentiment of text
        sentiment = TextBlob(text).sentiment.polarity
        sentiments.append(sentiment)

    if sentiments:
        mean = np.mean(sentiments)
        print(mean)
        return mean # return the mean sentiment of the stock over the day
    return None

# %%
get_sentiment('AAPL', datetime(2025, 5, 5))
# Out:
# {'status': 'ok', 'totalResults': 52, 'articles': [{'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'wedwards@businessinsider.com (William Edwards)', 'title': 'BI Whale Watch: 9 stocks that investing legends like Warren Buffett are betting at least 20% of their portfolios on', 'description': "Warren Buffett is stepping down. Here's the one stock he's betting 28% of his portfolio on.", 'url': 'https://www.businessinsider.com/warren-buffett-stocks-top-investors-are-betting-on-whale-watch-2025-5', 'urlToImage': 'https://i.insider.com/6818f2683fe8d3928364f07e?width=921&format=jpeg', 'publishedAt': '2025-05-06T08:00:01Z', 'content': 'Warren Buffett, perhaps the greatest investor of all time, announced on Saturday that he would step down as CEO of Berkshire Hathaway at the end of the year.\r\nGiven the occasion, we thought it would … [+2779 chars]'}, {'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Ben Lovejoy', 'title': 'Warren Buffett says Apple made Berkshire more money than he ever did', 'description': 'When Apple CEO Tim Cook praised Warren Buffett at the weekend, it followed the billionaire investor modestly stating that Apple had made more money for his Berkshire Hathaway investment fund than he ever did through his other investment picks.\n\n\n\nBuffett also…', 'url': 'https://9to5mac.com/2025/05/06/warren-buffett-says-apple-made-berkshire-more-money-than-he-ever-did/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/05/Warren-Buffett-says-Apple-made-Berkshire-more-money-than-he-ever-did.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-06T12:37:58Z', 'content': 'When Apple CEO Tim Cook praised Warren Buffett at the weekend, it followed the billionaire investor modestly stating that Apple had made more money for his Berkshire Hathaway investment fund than he … [+1476 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Baab', 'title': "Microsoft is stealing Amazon's thunder in the cloud — and AI", 'description': 'With almost $10 trillion in combined market cap across Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), and Meta (META), last week’s Big Tech earnings weren’t just dry corporate updates. They were market-moving events.Read more...', 'url': 'https://qz.com/microsoft-amazon-cloud-aws-azure-ai-earnings-stock-1851778923', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/08425d1bc08f25ac0b600c0a2c96be91.jpg', 'publishedAt': '2025-05-05T09:00:00Z', 'content': 'With almost $10 trillion in combined market cap across Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), and Meta (META), last weeks Big Tech earnings werent just dry corporate updates. They were market… [+4727 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': 'Warren Buffett retires. 8 times he called the stock market right', 'description': 'With Warren Buffett officially stepping down after decades at the helm of Berkshire Hathaway (BRK.A), it’s tempting to believe that he’s leaving the game having already seen the final score. Over the course of his career, Buffett, long known as the “Oracle of…', 'url': 'https://qz.com/warren-buffett-retires-berkshire-hathaway-predictions-1851779117', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/5214de64140c3437e966ad8511b0c756.jpg', 'publishedAt': '2025-05-05T14:23:57Z', 'content': 'With Warren Buffett officially stepping down after decades at the helm of Berkshire Hathaway (BRK.A), its tempting to believe that hes leaving the game having already seen the final score. Over the c… [+1697 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Veteran Investor Stays “Neutral” on Apple (AAPL) Stock Amid Tariff Challenges, High Valuation', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_a070748e-b709-46d9-a08f-7dfff1afb5ed', 'u ...
# 0.02373412698412699
# np.float64(0.02373412698412699)

# %%
def gather_daily_sentiments(stocks, start_date, end_date):
    """
    For each date in [start_date, end_date], calls get_sentiment(stock, date)
    and returns a DataFrame of shape (n_dates * n_stocks) of daily polarity
    """

    dates = pd.date_range(start_date, end_date)
    # initialise and empy dataframe
    sentiments = pd.DataFrame(index=dates, columns=stocks, dtype=float)

    for date in dates:
        for stock in stocks:
            sentiments.at[date, stock] = get_sentiment(stock, date)
    return sentiments

def fetch_price_data(stocks, start_date, end_date):
    """
    Downloads daily OHLC data for each ticker in 'stocks' between start_date and end_date. Returns a dict mapping ticker to its dataframe
    """

    price_data = {}
    for stock in stocks:
        df = yf.download(
            stock,
            start = start_date.strftime('%Y-%m-%d'),
            end = (end_date + timedelta(days = 1)).strftime('%Y-%m-%d'),
            interval = '1d',
            progress = False
        )
        price_data[stock] = df[['Open', 'Close']] # keep only what is needed
    return price_data

# %%
price_dict
# Out:
# {'AAPL': Price             Open       Close
#  Ticker            AAPL        AAPL
#  Date
#  2025-04-28  210.000000  210.139999
#  2025-04-29  208.690002  211.210007
#  2025-04-30  209.300003  212.500000
#  2025-05-01  209.080002  213.320007
#  2025-05-02  206.089996  205.350006
#  2025-05-05  203.100006  198.889999
#  2025-05-06  198.210007  198.509995
#  2025-05-07  199.169998  196.250000
#  2025-05-08  197.720001  197.490005
#  2025-05-09  199.000000  198.529999,
#  'DNUT': Price       Open Close
#  Ticker      DNUT  DNUT
#  Date
#  2025-04-28  4.29  4.19
#  2025-04-29  4.15  4.14
#  2025-04-30  4.06  4.10
#  2025-05-01  4.12  4.22
#  2025-05-02  4.22  4.31
#  2025-05-05  4.30  4.27
#  2025-05-06  4.29  4.36
#  2025-05-07  4.40  4.33
#  2025-05-08  3.03  3.26
#  2025-05-09  3.27  2.73,
#  'BRK-B': Price             Open       Close
#  Ticker           BRK-B       BRK-B
#  Date
#  2025-04-28  533.630005  530.940002
#  2025-04-29  531.000000  534.570007
#  2025-04-30  531.510010  533.250000
#  2025-05-01  531.000000  530.229980
#  2025-05-02  536.750000  539.799988
#  2025-05-05  520.080017  512.150024
#  2025-05-06  509.570007  512.330017
#  2025-05-07  515.020020  518.219971
#  2025-05-08  520.979980  513.250000
#  2025-05-09  514.250000  513.739990}

# %%
# Define parameters for the API and its functions

START_DATE = pd.to_datetime('2025-04-28')
END_DATE = pd.to_datetime('2025-05-09')
STOCK_UNIVERSE = ['AAPL', 'DNUT', 'BRK-B']

#1) Get your sentiment surface

sentiment_df = gather_daily_sentiments(STOCK_UNIVERSE, START_DATE, END_DATE)

# 2) Pull in all your price data

price_dict = fetch_price_data(STOCK_UNIVERSE, START_DATE, END_DATE)

# Now you will have:
# - sentiment_df.loc[date, stock] which is polarity of the stock on that date
# - price_dict[stock].loc[date, ['Open', 'Close']] prices

# Daily sentiment per stock

sentiment_df

# Price data for each stock

print(price_dict['DNUT'])
# Out:
# {'status': 'ok', 'totalResults': 70, 'articles': [{'source': {'id': None, 'name': 'AppleInsider'}, 'author': 'news@appleinsider.com (Wesley Hilliard)', 'title': 'Consumers get ahead of tariffs, Morgan Stanley hikes AAPL price target to $235', 'description': "Morgan Stanley hiked its Apple stock price target to $235 because instability created by the Trump administration's tariffs may be a boon to Apple's bottom line — at least in the short term.iPhone 16 Pro Max could have seen a sale bump in early 2025Even after…", 'url': 'https://appleinsider.com/articles/25/04/28/consumers-get-ahead-of-tariffs-morgan-stanley-hikes-aapl-price-target-to-235', 'urlToImage': 'https://photos5.appleinsider.com/gallery/63435-131825-Cameras-16-Pro-Max-xl.jpg', 'publishedAt': '2025-04-28T20:47:49Z', 'content': "Morgan Stanley hiked its Apple stock price target to $235 because instability created by the Trump administration's tariffs may be a boon to Apple's bottom line — at least in the short term.\r\nEven af… [+3349 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Daniel Howley', 'title': "Trump says Jeff Bezos 'solved the problem' after White House attacks Amazon on tariff price labeling plan", 'description': 'The White House is hitting back at Amazon over reports that it will show the impact of tariffs on prices of products it sells through its e-commerce store.', 'url': 'https://finance.yahoo.com/news/trump-says-jeff-bezos-solved-the-problem-after-white-house-attacks-amazon-on-tariff-price-labeling-plan-143310019.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Vy_qU754sCO3Q7Tc.X5cmQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-04/8f22dde0-2500-11f0-8fe9-c3b2af6663c7', 'publishedAt': '2025-04-29T14:33:10Z', 'content': 'Amazon (AMZN) is denying reports that it will display the impact of tariffs next to the price of products on its e-commerce site, which drew the ire of the Trump administration on Tuesday.\r\n"The team… [+3528 chars]'}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Jason Kirsch, Contributor, \n Jason Kirsch, Contributor\n https://www.forbes.com/sites/investor-hub/people/Jason-Kirsch/', 'title': 'Apple Stock Earnings Preview: Things To Consider Before The Next Report', 'description': 'Examine the key factors to watch before the next Apple earnings report to help you make informed decisions on AAPL.', 'url': 'https://www.forbes.com/sites/investor-hub/article/apple-aapl-stock-earnings-things-to-consider/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6807ef026a2cb38c08b48c67/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2025-04-28T11:00:00Z', 'content': "Apple's upcoming earnings report arrives at a critical juncture, with solid company fundamentals ... More potentially overshadowed by escalating macroeconomic and geopolitical challenges.\r\nGetty Imag… [+13710 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Daniel Howley', 'title': "White House blasts Amazon for 'hostile and political' tariff move", 'description': 'The White House is hitting back at Amazon over reports that it will show the impact of tariffs on prices of products it sells through its e-commerce store.', 'url': 'https://finance.yahoo.com/news/white-house-blasts-amazon-for-hostile-and-political-tariff-move-143310190.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Vy_qU754sCO3Q7Tc.X5cmQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-04/8f22dde0-2500-11f0-8fe9-c3b2af6663c7', 'publishedAt': '2025-04-29T14:33:10Z', 'content': 'Amazon (AMZN) is denying reports that it will display the impact of tariffs next to the price of products on its e-commerce site that drew the ire of the Trump administration on Tuesday.\r\nAccording t… [+3202 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'investors.com', 'title': 'Stock Market Today: Dow Jones ...
# 0.03969696969696971
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'ETF Daily News'}, 'author': 'MarketBeat News', 'title': 'Legal & General Group Plc Sells 5,472 Shares of Krispy Kreme, Inc. (NASDAQ:DNUT)', 'description': 'Legal & General Group Plc cut its holdings in shares of Krispy Kreme, Inc. (NASDAQ:DNUT – Free Report) by 5.4% during the 4th quarter, according to the company in its most recent disclosure with the Securities and Exchange Commission. The institutional invest…', 'url': 'https://www.etfdailynews.com/2025/04/28/legal-general-group-plc-sells-5472-shares-of-krispy-kreme-inc-nasdaqdnut/', 'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/krispy-kreme-inc-logo-1200x675.jpg?v=20240424143045&w=240&h=240&zc=2', 'publishedAt': '2025-04-28T07:56:53Z', 'content': 'Legal &amp; General Group Plc cut its holdings in shares of Krispy Kreme, Inc. (NASDAQ:DNUT – Free Report) by 5.4% during the 4th quarter, according to the company in its most recent disclosure with … [+5871 chars]'}]}
# 0.19999999999999998
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Adam Eckert', 'title': "Warren Buffett Reveals 'The One Easy Way To Become Worth 50% More Than You Are Now'", 'description': 'Legendary investor Warren Buffett says there’s an easy way to increase your worth by at least 50% — and it doesn’t have anything to do with picking stocks...', 'url': 'https://finance.yahoo.com/news/warren-buffett-reveals-one-easy-005329851.html', 'urlToImage': 'https://media.zenfs.com/en/Benzinga/b661b8a7d69498b2b819a8760b780f23', 'publishedAt': '2025-04-29T00:53:29Z', 'content': 'Legendary investor\xa0Warren Buffett\xa0says theres an easy way to increase your worth by at least 50% and it doesnt have anything to do with picking stocks.\r\nWhat To Know:\xa0Buffett, chairman and CEO of\xa0Ber… [+1946 chars]'}]}
# 0.380952380952381
# {'status': 'ok', 'totalResults': 58, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Daniel Howley', 'title': "Trump says Jeff Bezos 'solved the problem' after White House attacks Amazon on tariff price labeling plan", 'description': 'The White House is hitting back at Amazon over reports that it will show the impact of tariffs on prices of products it sells through its e-commerce store.', 'url': 'https://finance.yahoo.com/news/trump-says-jeff-bezos-solved-the-problem-after-white-house-attacks-amazon-on-tariff-price-labeling-plan-143310019.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Vy_qU754sCO3Q7Tc.X5cmQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-04/8f22dde0-2500-11f0-8fe9-c3b2af6663c7', 'publishedAt': '2025-04-29T14:33:10Z', 'content': 'Amazon (AMZN) is denying reports that it will display the impact of tariffs next to the price of products on its e-commerce site, which drew the ire of the Trump administration on Tuesday.\r\n"The team… [+3528 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': "Apple earnings are coming. Here's what to watch", 'description': 'Wall Street is about to find out just how far the Apple (AAPL) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its fiscal second-quarter earnings report on Thursday, the world’s most valuable tech company finds itself a…', 'url': 'https://qz.com/apple-q2-earnings-preview-tariffs-iphone-ipad-tim-cook-1851778363', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/1f294c60cb8fa24125f0d5e7a9560503.jpg', 'publishedAt': '2025-04-30T09:00:00Z', 'content': 'In This Story\r\nWall Street is about to find out just how far the Apple (AAPL+0.52%\r\n) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its fiscal second-quarter… [+5621 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Daniel Howley', 'title': "White House blasts Amazon for 'hostile and political' tariff move", 'description': 'The White House is hitting back at Amazon over reports that it will show the impact of tariffs on prices of products it sells through its e-commerce store.', 'url': 'https://finance.yahoo.com/news/white-house-blasts-amazon-for-hostile-and-political-tariff-move-143310190.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Vy_qU754sCO3Q7Tc.X5cmQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-04/8f22dde0-2500-11f0-8fe9-c3b2af6663c7', 'publishedAt': '2025-04-29T14:33:10Z', 'content': 'Amazon (AMZN) is denying reports that it will display the impact of tariffs next to the price of products on its e-commerce site that drew the ire of the Trump administration on Tuesday.\r\nAccording t… [+3202 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Shannon Carroll', 'title': "Apple earnings are coming. Here's what to watch", 'description': 'Wall Street is about to find out just how far the Apple (AAPL) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its...', 'url': 'https://finance.yahoo.com/news/apple-earnings-coming-heres-watch-090000718.html', 'urlToImage': 'https://media.zenfs.com/en/quartz.com/aa315dcc0dad5f6dbb89823fa51f2082', 'publishedAt': '2025-04-30T09:00:00Z', 'content': 'Photo: Justin Sullivan (Getty Images)\r\nWall Street is about to find out just how far the Apple (AAPL) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its fisca… [+5608 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Hamna Asim', 'title': 'Is Apple Inc. (AAPL) Among The Best Warren Buffett Stock Picks For Beginners?', 'description': 'We recently published a list of 12 Best Warren Buffett Stock Picks For Beginners. In this article, we are going to take a look at where Apple Inc. ...
# 0.18333333333333332
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 2, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Adam Eckert', 'title': "Warren Buffett Reveals 'The One Easy Way To Become Worth 50% More Than You Are Now'", 'description': 'Legendary investor Warren Buffett says there’s an easy way to increase your worth by at least 50% — and it doesn’t have anything to do with picking stocks...', 'url': 'https://finance.yahoo.com/news/warren-buffett-reveals-one-easy-005329851.html', 'urlToImage': 'https://media.zenfs.com/en/Benzinga/b661b8a7d69498b2b819a8760b780f23', 'publishedAt': '2025-04-29T00:53:29Z', 'content': 'Legendary investor\xa0Warren Buffett\xa0says theres an easy way to increase your worth by at least 50% and it doesnt have anything to do with picking stocks.\r\nWhat To Know:\xa0Buffett, chairman and CEO of\xa0Ber… [+1946 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Sheryar Siddiq', 'title': 'Berkshire Hathaway Inc. (BRK-A): Among the Best Stocks to Buy According to the Bill & Melinda Gates Foundation Trust', 'description': 'We recently compiled a list of the 10 Best Stocks to Buy According to the Bill & Melinda Gates Foundation Trust. In this article, we are going to take a look...', 'url': 'https://finance.yahoo.com/news/berkshire-hathaway-inc-brk-among-134326831.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/MJF0wSMWqKYI8b.rKoTXYg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzM-/https://media.zenfs.com/en/insidermonkey.com/71b73ee0cc91ebfae2296b9726a1eba8', 'publishedAt': '2025-04-30T13:43:26Z', 'content': 'We recently compiled a list of the 10 Best Stocks to Buy According to the Bill &amp; Melinda Gates Foundation Trust.\xa0In this article, we are going to take a look at where Berkshire Hathaway Inc. (NYS… [+5018 chars]'}]}
# 0.5238095238095238
# {'status': 'ok', 'totalResults': 64, 'articles': [{'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Zac Hall', 'title': 'Apple reports Q2 2025 earnings with $95.4 billion in revenue', 'description': 'Apple has\xa0released\xa0its earnings report for fiscal Q2 2025. The company reports $95.4 billion in revenue during the three-month period. That compares to $90.75 billion during the same quarter a year ago. Wall Street expected $94.68 billion in revenue. Profit f…', 'url': 'https://9to5mac.com/2025/05/01/apple-reports-q2-2025-earnings-with-95-4-billion-in-revenue/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/02/apple-earnings.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-01T20:33:13Z', 'content': 'Apple has\xa0released\xa0its earnings report for fiscal Q2 2025. The company reports $95.4 billion in revenue during the three-month period. That compares to $90.75 billion during the same quarter a year a… [+1668 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': "Apple earnings are coming. Here's what to watch", 'description': 'Wall Street is about to find out just how far the Apple (AAPL) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its fiscal second-quarter earnings report on Thursday, the world’s most valuable tech company finds itself a…', 'url': 'https://qz.com/apple-q2-earnings-preview-tariffs-iphone-ipad-tim-cook-1851778363', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/1f294c60cb8fa24125f0d5e7a9560503.jpg', 'publishedAt': '2025-04-30T09:00:00Z', 'content': 'In This Story\r\nWall Street is about to find out just how far the Apple (AAPL+0.52%\r\n) may fall from its trillion-dollar tree. As the Silicon Valley giant prepares to release its fiscal second-quarter… [+5621 chars]'}, {'source': {'id': None, 'name': 'MacRumors'}, 'author': 'Juli Clover', 'title': "Apple's Q2 2025 Earnings Call Takeaways", 'description': 'Apple held its earnings call for the second fiscal quarter of 2025 today (second calendar quarter), announcing revenue of $95.4 billion and net quarterly profit of $28.4 billion. During the call, Apple CEO Tim Cook spoke about tariffs, the App Store changes A…', 'url': 'https://www.macrumors.com/2025/05/01/apple-earnings-call-q2-2025/', 'urlToImage': 'https://images.macrumors.com/t/xkVHlBaujx_SDb1_mm4VSNOI50g=/2676x/article-new/2022/01/Apple-Logo-Cash-Feature-Yellow.jpg', 'publishedAt': '2025-05-01T22:09:45Z', 'content': 'Apple held its earnings call for the second fiscal quarter of 2025 today (second calendar quarter), announcing revenue of $95.4 billion and net quarterly profit of $28.4 billion. During the call, App… [+3095 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': 'Apple tops Wall Street earnings expectations but its closely watched services business misses', 'description': 'The iPhone maker continued to show solid growth behind its services department and amid macroeconomic concerns', 'url': 'https://qz.com/apple-q2-earnings-report-iphone-ipad-tariffs-1851778721', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/970eeb91da5e2e1773d306cd35136051.jpg', 'publishedAt': '2025-05-01T20:51:29Z', 'content': 'In This Story\r\nFiscal second-quarter earnings show that the Apple (AAPL-0.39%\r\n) is as shiny as ever.\r\nThursday after the bell, the company reported $95.4 billion in revenue, up 5% year over year, an… [+1321 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'barchart.com', 'title': 'As Apple Intelligence Adoption Outperforms Estimates, Should You Buy AAPL Stock?', 'description': 'Less than $10/month! View ALL results for your Stocks, ETFs and Funds Screeners with Barchart Plus.\nFREE 30 Day Trial\n- Market Pulse\n- VolatilityVolume & Open InterestHorizontal StrategiesButterfly Strategies\n-\n- ResourcesEuropean FuturesE ...
# 0.0027777777777777705
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Sheryar Siddiq', 'title': 'Berkshire Hathaway Inc. (BRK-A): Among the Best Stocks to Buy According to the Bill & Melinda Gates Foundation Trust', 'description': 'We recently compiled a list of the 10 Best Stocks to Buy According to the Bill & Melinda Gates Foundation Trust. In this article, we are going to take a look...', 'url': 'https://finance.yahoo.com/news/berkshire-hathaway-inc-brk-among-134326831.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/MJF0wSMWqKYI8b.rKoTXYg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzM-/https://media.zenfs.com/en/insidermonkey.com/71b73ee0cc91ebfae2296b9726a1eba8', 'publishedAt': '2025-04-30T13:43:26Z', 'content': 'We recently compiled a list of the 10 Best Stocks to Buy According to the Bill &amp; Melinda Gates Foundation Trust.\xa0In this article, we are going to take a look at where Berkshire Hathaway Inc. (NYS… [+5018 chars]'}]}
# 0.6666666666666666
# {'status': 'ok', 'totalResults': 71, 'articles': [{'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Seth Kurkowski', 'title': '9to5Mac Daily: May 2, 2025 – AAPL earnings, big App Store changes', 'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by CardPointers:…', 'url': 'https://9to5mac.com/2025/05/02/daily-may-2-2025/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-02T15:26:44Z', 'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+900 chars]'}, {'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Zac Hall', 'title': 'Apple reports Q2 2025 earnings with $95.4 billion in revenue', 'description': 'Apple has\xa0released\xa0its earnings report for fiscal Q2 2025. The company reports $95.4 billion in revenue during the three-month period. That compares to $90.75 billion during the same quarter a year ago. Wall Street expected $94.68 billion in revenue. Profit f…', 'url': 'https://9to5mac.com/2025/05/01/apple-reports-q2-2025-earnings-with-95-4-billion-in-revenue/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2024/02/apple-earnings.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-01T20:33:13Z', 'content': 'Apple has\xa0released\xa0its earnings report for fiscal Q2 2025. The company reports $95.4 billion in revenue during the three-month period. That compares to $90.75 billion during the same quarter a year a… [+1668 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Arnst', 'title': 'Apple says tariffs will cost it a whopping $900 million this quarter', 'description': 'Tariffs are about to hit Apple (AAPL) — and hard. As Big Tech and other firms continue to grapple with the Trump administration’s shifting tariff policies, Apple CEO Tim Cook said during the company’s latest earnings call that tariffs could cost it $900 milli…', 'url': 'https://qz.com/apple-earnings-tariffs-cost-tim-cook-chip-iphones-china-1851778838', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/b2077e4aff675977568acb24156c6c93.jpg', 'publishedAt': '2025-05-02T15:38:36Z', 'content': 'In This Story\r\nTariffs are about to hit Apple (AAPL) and hard. As Big Tech and other firms continue to grapple with the Trump administrations shifting tariff policies, Apple CEO Tim Cook said during … [+1798 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': 'Apple earnings takeaways: A rush to buy iPhones before tariffs, a $900 million hit, and more', 'description': 'Apple (AAPL) delivered solid second-quarter earnings — but you wouldn’t exactly know it from the mood on Wall Street. Despite beating expectations for the fifth straight quarter, investors were less focused on what Apple just reported and more on what lies ah…', 'url': 'https://qz.com/apple-q2-2025-earnings-tariffs-china-iphones-services-1851778851', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/5a41ed0fc63bb005e72fc08154a7021f.jpg', 'publishedAt': '2025-05-02T16:07:00Z', 'content': 'Apple (AAPL) delivered solid second-quarter earnings but you wouldnt exactly know it from the mood on Wall Street. Despite beating expectations for the fifth straight quarter, investors were less foc… [+8139 chars]'}, {'source': {'id': None, 'name': 'MacRumors'}, 'author': 'Juli Clover', 'title': "Apple's Q2 2025 Earnings Call Takeaways", 'description': 'Apple held its earnings call for the second  ...
# 0.06277777777777778
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'Stockcharts.com'}, 'author': 'Jayanthi Gopalakrishnan', 'title': 'Stock Market Wrap: Stocks Rebound as May Kicks Off with a Bang—What Investors Should Know', 'description': 'We just wrapped up a busy week jam-packed with key economic data and big tech earnings. And we have some positive news: the market held up pretty well. May is off to a good start.Strong earnings from META Platforms (META) and Microsoft (MSFT) gave the stock m…', 'url': 'https://stockcharts.com/articles/chartwatchers/2025/05/stock-market-wrap-stocks-rebou-188.html', 'urlToImage': 'https://stockcharts.com/img/articles/2025/05/02/6e42dbe4-fcf5-4243-b46a-eaf048afaf20.jpg', 'publishedAt': '2025-05-02T22:05:33Z', 'content': '<ul><li>A strong jobs report sparked a stock market rally, with major indexes closing the week higher.</li><li>Positive earnings from Microsoft and Meta Platforms took the Nasdaq Composite above its … [+5902 chars]'}]}
# 0.21103896103896105
# {'status': 'ok', 'totalResults': 54, 'articles': [{'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Seth Kurkowski', 'title': '9to5Mac Daily: May 2, 2025 – AAPL earnings, big App Store changes', 'description': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apple’s Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overcast and other podcast players.\n\n\n\nSponsored by CardPointers:…', 'url': 'https://9to5mac.com/2025/05/02/daily-may-2-2025/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/12/9to5Mac-Daily-art-lead.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-02T15:26:44Z', 'content': 'Listen to a recap of the top stories of the day from\xa09to5Mac. 9to5Mac Daily is available\xa0on iTunes and Apples Podcasts app,\xa0Stitcher,\xa0TuneIn,\xa0Google Play, or through our\xa0dedicated RSS feed\xa0for Overca… [+900 chars]'}, {'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Zac Hall', 'title': 'Tim Cook on Warren Buffett: ‘one of the great privileges of my life to know him’', 'description': 'Berkshire Hathaway CEO and longtime Apple backer Warren Buffett announced today that he will retire at the end of 2025. Buffett, 94, spent more than six decades at the helm of Berkshire Hathaway, which was Apple’s largest institutional shareholder until last …', 'url': 'https://9to5mac.com/2025/05/03/tim-cook-on-warren-buffett-one-of-the-great-privileges-of-my-life-to-know-him/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/05/tim-cook-warren-buffett.webp?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-03T19:42:27Z', 'content': 'Berkshire Hathaway CEO and longtime Apple backer Warren Buffett announced today that he will retire at the end of 2025. Buffett, 94, spent more than six decades at the helm of Berkshire Hathaway, whi… [+2454 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Arnst', 'title': 'Apple says tariffs will cost it a whopping $900 million this quarter', 'description': 'Tariffs are about to hit Apple (AAPL) — and hard. As Big Tech and other firms continue to grapple with the Trump administration’s shifting tariff policies, Apple CEO Tim Cook said during the company’s latest earnings call that tariffs could cost it $900 milli…', 'url': 'https://qz.com/apple-earnings-tariffs-cost-tim-cook-chip-iphones-china-1851778838', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/b2077e4aff675977568acb24156c6c93.jpg', 'publishedAt': '2025-05-02T15:38:36Z', 'content': 'In This Story\r\nTariffs are about to hit Apple (AAPL) and hard. As Big Tech and other firms continue to grapple with the Trump administrations shifting tariff policies, Apple CEO Tim Cook said during … [+1798 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': 'Apple earnings takeaways: A rush to buy iPhones before tariffs, a $900 million hit, and more', 'description': 'Apple (AAPL) delivered solid second-quarter earnings — but you wouldn’t exactly know it from the mood on Wall Street. Despite beating expectations for the fifth straight quarter, investors were less focused on what Apple just reported and more on what lies ah…', 'url': 'https://qz.com/apple-q2-2025-earnings-tariffs-china-iphones-services-1851778851', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/5a41ed0fc63bb005e72fc08154a7021f.jpg', 'publishedAt': '2025-05-02T16:07:00Z', 'content': 'Apple (AAPL) delivered solid second-quarter earnings but you wouldnt exactly know it from the mood on Wall Street. Despite beating expectations for the fifth straight quarter, investors were less foc… [+8139 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Quartz Intelligence Newsroom', 'title': "Mark Zuckerberg's Meta dreams, Microsoft's ear ...
# 0.10823232323232324
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 8, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Berkshire Hathaway (BRK-B) Transitions Leadership as Abel Assumes CEO Responsibilities', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_9a53f8c9-26ab-476e-a34d-40207b93d10b', 'urlToImage': None, 'publishedAt': '2025-05-03T13:17:41Z', 'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+702 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Myles Udland', 'title': 'Berkshire Hathaway annual meeting: Buffett recommends Abel take over as CEO at year end', 'description': 'The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting, hosted by CEO Warren Buffett, is here.', 'url': 'https://finance.yahoo.com/news/live/berkshire-hathaway-annual-meeting-buffett-recommends-abel-take-over-as-ceo-at-year-end-114823075.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2025-05/d134d6b0-2849-11f0-9d6b-5938dafc1905', 'publishedAt': '2025-05-03T11:48:23Z', 'content': "A classic Warren Buffett quote.\r\nIn a sprawling response to a question about the company's cash pile, Buffett hit on a few key ideas.\r\nThe first, serious but also light-hearted, is that he's not hoar… [+1775 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Myles Udland', 'title': 'Berkshire Hathaway annual meeting: Buffett set to take the stage in Omaha', 'description': 'Warren Buffett is set to take questions from Berkshire Hathaway shareholders for nearly six hours on Saturday.', 'url': 'https://finance.yahoo.com/news/live/berkshire-hathaway-annual-meeting-buffett-set-to-take-the-stage-in-omaha-114823143.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/xj4UIeaKOUgRvGeyn__9rg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04ODU-/https://s.yimg.com/os/creatr-uploaded-images/2025-05/58c8d8a0-2814-11f0-abed-278ada26b15a', 'publishedAt': '2025-05-03T11:48:23Z', 'content': 'The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is here.\r\nCalled "Woodstock for Capitalists," the weekend\'s main event is set to kick off this morning with Warren Buffett taking ques… [+2165 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': "Berkshire Hathaway annual meeting: Buffett says trade 'should not be a weapon'", 'description': 'In This Article:\nThe annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is underway.\nCalled "Woodstock for Capitalists," the weekend\'s main event kicked off with legendary investor Warren Buffett taking questions from CNBC\'s Becky Quick and Berkshir…', 'url': 'https://biztoc.com/x/7dedf5cde5e1dae2', 'urlToImage': 'https://biztoc.com/cdn/7dedf5cde5e1dae2_s.webp', 'publishedAt': '2025-05-03T13:38:00Z', 'content': 'In This Article:The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is underway.Called "Woodstock for Capitalists," the weekend\'s main event kicked off with legendary investor Warren Buf… [+146 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': 'Berkshire Hathaway annual meeting: Buffett set to take the stage in Omaha', 'description': 'In This Article:\nThe annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is here.\nCalled "Woodstock for Capitalists," the weekend\'s main event is set to kick off this morning with Warren Buffett taking questions from CNBC\'s Becky Quick as well as Ber…', 'url': 'https://biztoc.com/x/bac145833c6ee607', 'urlToImage': 'https://biztoc.com/cdn/bac145833c6ee607_s.webp', 'publishedAt': '2025-05-03T12:10:15Z', 'content': 'In This Article:The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is here.Called "Woodstock for Capitalists," the weekend\'s main event is set to kick off t ...
# 0.16999999999999998
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Zac Hall', 'title': 'Tim Cook on Warren Buffett: ‘one of the great privileges of my life to know him’', 'description': 'Berkshire Hathaway CEO and longtime Apple backer Warren Buffett announced today that he will retire at the end of 2025. Buffett, 94, spent more than six decades at the helm of Berkshire Hathaway, which was Apple’s largest institutional shareholder until last …', 'url': 'https://9to5mac.com/2025/05/03/tim-cook-on-warren-buffett-one-of-the-great-privileges-of-my-life-to-know-him/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/05/tim-cook-warren-buffett.webp?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-03T19:42:27Z', 'content': 'Berkshire Hathaway CEO and longtime Apple backer Warren Buffett announced today that he will retire at the end of 2025. Buffett, 94, spent more than six decades at the helm of Berkshire Hathaway, whi… [+2454 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Baab', 'title': 'Disney, Palantir, AMD and more stocks to watch this week', 'description': 'After blockbuster earnings last week from Big Tech, capped by Apple (AAPL), Amazon (AMZN), and a weekend of Buffett wisdom at Berkshire Hathaway’s (BRK.A) annual meeting, markets are still digesting what it all means. The Dow, S&P, and Nasdaq are rallying, bu…', 'url': 'https://qz.com/disney-palantir-amd-uber-coinbase-earnings-stock-market-1851778787', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/9bddd5ed918e7beba861dee65ec00122.jpg', 'publishedAt': '2025-05-04T09:00:00Z', 'content': 'In This Story\r\nAfter blockbuster earnings last week from Big Tech, capped by Apple (AAPL-0.39%\r\n), Amazon (AMZN-2.87%\r\n), and a weekend of Buffett wisdom at Berkshire Hathaways (BRK.A-0.82%\r\n) annual… [+4852 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Quartz Intelligence Newsroom', 'title': "Mark Zuckerberg's Meta dreams, Microsoft's earnings smash, and Reddit's surprise: Tech news roundup", 'description': 'For the past two years, tech giants have been racing to build the digital backbone of the artificial intelligence boom, spending tens of billions of dollars on chips and new data centers. Now, as construction cranes swing and server racks pile up, early signs…', 'url': 'https://qz.com/mark-zuckerberg-meta-microsoft-amazon-nvidia-ai-tech-1851778870', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/071ee112066239555a7f7ee06974056f.jpg', 'publishedAt': '2025-05-03T11:00:00Z', 'content': 'Fiscal second-quarter earnings show that the Apple (AAPL) hasnt lost its shine.\r\nThursday after the bell, Apple reported $95.4 billion in revenue, up 5% year-over-year, and quarterly diluted earnings… [+345 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Was Jim Cramer Right About Apple (AAPL)?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_d6a2d71e-cfe0-4d85-9750-bd235ddc386e', 'urlToImage': None, 'publishedAt': '2025-05-04T22:21:16Z', 'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+702 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Bill Stone, Contributor, \n Bill Stone, Contributor\n https://www.forbes.com/sites/bill_stone/', 'title': 'Earnings Season And Waiting On The Fed', 'description': 'Despite the negative GDP results, the US economy is not in a recession. Earnings season has been strong, and Warren Buffett announced significant changes at Berkshire.', 'url': 'https://www.forbes.com/sites/bill_stone/2025/05/04/earnings-season-and-waiting-on-the-fed/', 'urlToImage': 'https://imageio.forbes.com/specials-im ...
# 0.1598196248196248
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 9, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Berkshire Hathaway (BRK-B) Transitions Leadership as Abel Assumes CEO Responsibilities', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_9a53f8c9-26ab-476e-a34d-40207b93d10b', 'urlToImage': None, 'publishedAt': '2025-05-03T13:17:41Z', 'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+702 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Myles Udland', 'title': 'Berkshire Hathaway annual meeting: Buffett recommends Abel take over as CEO at year end', 'description': 'The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting, hosted by CEO Warren Buffett, is here.', 'url': 'https://finance.yahoo.com/news/live/berkshire-hathaway-annual-meeting-buffett-recommends-abel-take-over-as-ceo-at-year-end-114823075.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2025-05/d134d6b0-2849-11f0-9d6b-5938dafc1905', 'publishedAt': '2025-05-03T11:48:23Z', 'content': "A classic Warren Buffett quote.\r\nIn a sprawling response to a question about the company's cash pile, Buffett hit on a few key ideas.\r\nThe first, serious but also light-hearted, is that he's not hoar… [+1775 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Bill Stone, Contributor, \n Bill Stone, Contributor\n https://www.forbes.com/sites/bill_stone/', 'title': 'Earnings Season And Waiting On The Fed', 'description': 'Despite the negative GDP results, the US economy is not in a recession. Earnings season has been strong, and Warren Buffett announced significant changes at Berkshire.', 'url': 'https://www.forbes.com/sites/bill_stone/2025/05/04/earnings-season-and-waiting-on-the-fed/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6817d5c58c7138906d129954/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2025-05-04T21:16:07Z', 'content': 'Beyond tariffs and earnings, the big event will be the Federal Reserve meeting on Wednesday. Markets ... More expect no rate changes from the Federal Reserve. The focus will be on Chair Powells comme… [+5950 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Myles Udland', 'title': 'Berkshire Hathaway annual meeting: Buffett set to take the stage in Omaha', 'description': 'Warren Buffett is set to take questions from Berkshire Hathaway shareholders for nearly six hours on Saturday.', 'url': 'https://finance.yahoo.com/news/live/berkshire-hathaway-annual-meeting-buffett-set-to-take-the-stage-in-omaha-114823143.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/xj4UIeaKOUgRvGeyn__9rg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04ODU-/https://s.yimg.com/os/creatr-uploaded-images/2025-05/58c8d8a0-2814-11f0-abed-278ada26b15a', 'publishedAt': '2025-05-03T11:48:23Z', 'content': 'The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is here.\r\nCalled "Woodstock for Capitalists," the weekend\'s main event is set to kick off this morning with Warren Buffett taking ques… [+2165 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': "Berkshire Hathaway annual meeting: Buffett says trade 'should not be a weapon'", 'description': 'In This Article:\nThe annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is underway.\nCalled "Woodstock for Capitalists," the weekend\'s main event kicked off with legendary investor Warren Buffett taking questions from CNBC\'s Becky Quick and Berkshir…', 'url': 'https://biztoc.com/x/7dedf5cde5e1dae2', 'urlToImage': 'https://biztoc.com/cdn/7dedf5cde5e1dae2_s.webp', 'publishedAt': '2025-05-03T13:38:00Z', 'content': 'In This Article:The annual Berkshire Hathaway (BRK-A, BRK-B) shareholder meeting is underway. ...
# 0.15388888888888888
# {'status': 'ok', 'totalResults': 43, 'articles': [{'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Baab', 'title': "Microsoft is stealing Amazon's thunder in the cloud — and AI", 'description': 'With almost $10 trillion in combined market cap across Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), and Meta (META), last week’s Big Tech earnings weren’t just dry corporate updates. They were market-moving events.Read more...', 'url': 'https://qz.com/microsoft-amazon-cloud-aws-azure-ai-earnings-stock-1851778923', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/08425d1bc08f25ac0b600c0a2c96be91.jpg', 'publishedAt': '2025-05-05T09:00:00Z', 'content': 'With almost $10 trillion in combined market cap across Microsoft (MSFT), Amazon (AMZN), Apple (AAPL), and Meta (META), last weeks Big Tech earnings werent just dry corporate updates. They were market… [+4727 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Baab', 'title': 'Disney, Palantir, AMD and more stocks to watch this week', 'description': 'After blockbuster earnings last week from Big Tech, capped by Apple (AAPL), Amazon (AMZN), and a weekend of Buffett wisdom at Berkshire Hathaway’s (BRK.A) annual meeting, markets are still digesting what it all means. The Dow, S&P, and Nasdaq are rallying, bu…', 'url': 'https://qz.com/disney-palantir-amd-uber-coinbase-earnings-stock-market-1851778787', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/9bddd5ed918e7beba861dee65ec00122.jpg', 'publishedAt': '2025-05-04T09:00:00Z', 'content': 'In This Story\r\nAfter blockbuster earnings last week from Big Tech, capped by Apple (AAPL-0.39%\r\n), Amazon (AMZN-2.87%\r\n), and a weekend of Buffett wisdom at Berkshire Hathaways (BRK.A-0.82%\r\n) annual… [+4852 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Shannon Carroll', 'title': 'Warren Buffett retires. 8 times he called the stock market right', 'description': 'With Warren Buffett officially stepping down after decades at the helm of Berkshire Hathaway (BRK.A), it’s tempting to believe that he’s leaving the game having already seen the final score. Over the course of his career, Buffett, long known as the “Oracle of…', 'url': 'https://qz.com/warren-buffett-retires-berkshire-hathaway-predictions-1851779117', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/5214de64140c3437e966ad8511b0c756.jpg', 'publishedAt': '2025-05-05T14:23:57Z', 'content': 'With Warren Buffett officially stepping down after decades at the helm of Berkshire Hathaway (BRK.A), its tempting to believe that hes leaving the game having already seen the final score. Over the c… [+1697 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Was Jim Cramer Right About Apple (AAPL)?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_d6a2d71e-cfe0-4d85-9750-bd235ddc386e', 'urlToImage': None, 'publishedAt': '2025-05-04T22:21:16Z', 'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+702 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Bill Stone, Contributor, \n Bill Stone, Contributor\n https://www.forbes.com/sites/bill_stone/', 'title': 'Earnings Season And Waiting On The Fed', 'description': 'Despite the negative GDP results, the US economy is not in a recession. Earnings season has been strong, and Warren Buffett announced significant changes at Berkshire.', 'url': 'https://www.forbes.com/sites/bill_stone/2025/05/04/earnings-season-and-waiting-on-the-fed/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6817d5c58c7138906d129954/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2025-05-04T21:16:07Z', 'content': 'Beyond tari ...
# 0.12890476190476188
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': None, 'name': 'ETF Daily News'}, 'author': 'MarketBeat News', 'title': 'Krispy Kreme, Inc. (NASDAQ:DNUT) Given Average Recommendation of “Moderate Buy” by Brokerages', 'description': 'Shares of Krispy Kreme, Inc. (NASDAQ:DNUT – Get Free Report) have received a consensus rating of “Moderate Buy” from the eight analysts that are covering the firm, Marketbeat.com reports. One analyst has rated the stock with a sell recommendation, one has giv…', 'url': 'https://www.etfdailynews.com/2025/05/05/krispy-kreme-inc-nasdaqdnut-given-average-recommendation-of-moderate-buy-by-brokerages/', 'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/krispy-kreme-inc-logo-1200x675.jpg?v=20240424143045&w=240&h=240&zc=2', 'publishedAt': '2025-05-05T06:38:54Z', 'content': 'Shares of Krispy Kreme, Inc. (NASDAQ:DNUT – Get Free Report) have received a consensus rating of “Moderate Buy” from the eight analysts that are covering the firm, Marketbeat.com reports. One analyst… [+5428 chars]'}]}
# 0.009999999999999998
# {'status': 'ok', 'totalResults': 12, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Brad Smith', 'title': "Warren Buffett's succession plan & net worth: What to know", 'description': 'It was announced over the weekend that Warren Buffett will step down as CEO of Berkshire Hathaway (BRK-B, BRK-A) at the end of 2025, handing the role to vice...', 'url': 'https://finance.yahoo.com/video/warren-buffetts-succession-plan-net-164111577.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/xxPtsS38JMQGvuBuQUonYA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzY-/https://s.yimg.com/os/creatr-uploaded-images/2025-05/7259af00-29cd-11f0-bfff-ffadf006049b', 'publishedAt': '2025-05-05T16:41:11Z', 'content': "Warren Buffett says the time has arrived to begin the CEO succession plan for Berkshire Hathaway. The 94-year-old investing legend plans to hand over the position to Berkshire's vice chairman, Greg A… [+1386 chars]"}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'Bill Stone, Contributor, \n Bill Stone, Contributor\n https://www.forbes.com/sites/bill_stone/', 'title': 'Earnings Season And Waiting On The Fed', 'description': 'Despite the negative GDP results, the US economy is not in a recession. Earnings season has been strong, and Warren Buffett announced significant changes at Berkshire.', 'url': 'https://www.forbes.com/sites/bill_stone/2025/05/04/earnings-season-and-waiting-on-the-fed/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6817d5c58c7138906d129954/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2025-05-04T21:16:07Z', 'content': 'Beyond tariffs and earnings, the big event will be the Federal Reserve meeting on Wednesday. Markets ... More expect no rate changes from the Federal Reserve. The focus will be on Chair Powells comme… [+5950 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Rian Howlett', 'title': 'Stock market today: Dow, S&P 500, Nasdaq slide as tariff fears revive to kick off big Fed week', 'description': 'A cool-down might be on the horizon as major index futures slip following a record-breaking run of gains for the S&P 500.', 'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-slide-as-tariff-fears-revive-to-kick-off-big-fed-week-133033489.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ly9SsWZMZ745tk6gZspIUw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-05/52515090-293d-11f0-beff-8bca14617f06', 'publishedAt': '2025-05-05T13:31:04Z', 'content': "US stocks fell on Monday, set for a retreat from a historic run of gains as President Trump's new tariff threat revived trade war worries in the wait for a Federal Reserve policy decision.\r\nThe S&amp… [+5648 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Rian Howlett', 'title': 'Stock market today: Dow, S&P 500, Nasdaq pause rally as tariff fears revive to kick off big Fed week', 'description': "Trump's latest tariff threat has reignited worries about a global trade war.", 'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-pause-rally-as-tariff-fears-revive-to-kick-off-big-fed-week-133104574.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ly9SsWZMZ745tk6gZspIUw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-05/52515090-293d-11f0-beff-8bca14617f06', 'publishedAt': '2025-05-05T13:31:04Z', 'content': "US stocks were mixed on Monday, set for a retreat from a historic run of gains as President Trump's new tariff threat revived trade war worries in the wait for a Federal Reserve policy decision.\r\nThe… [+8147 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Rian Howlett', 'title': 'Stock market today: S&P 500, Nasdaq pause rally as tariff fears revive to kick off big Fed week', 'description': "Trump's latest tariff threat has reignited worries abo ...
# 0.11435185185185184
# ...
# 0.05157407407407407
# {'status': 'ok', 'totalResults': 55, 'articles': [{'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'wedwards@businessinsider.com (William Edwards)', 'title': 'BI Whale Watch: 9 stocks that investing legends like Warren Buffett are betting at least 20% of their portfolios on', 'description': "Warren Buffett is stepping down. Here's the one stock he's betting 28% of his portfolio on.", 'url': 'https://www.businessinsider.com/warren-buffett-stocks-top-investors-are-betting-on-whale-watch-2025-5', 'urlToImage': 'https://i.insider.com/6818f2683fe8d3928364f07e?width=921&format=jpeg', 'publishedAt': '2025-05-06T08:00:01Z', 'content': 'Warren Buffett, perhaps the greatest investor of all time, announced on Saturday that he would step down as CEO of Berkshire Hathaway at the end of the year.\r\nGiven the occasion, we thought it would … [+2779 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Niamh Rowe', 'title': 'Apple wants to move to AI-powered search — and Google stock sinks 8%', 'description': 'Apple Inc. (AAPL) is exploring how to incorporate AI-powered search engines on its devices — and it’s sending Google’s (GOOGL) share price tumbling. Read more...', 'url': 'https://qz.com/apple-google-ai-search-engine-lawsuit-alphabet-1851779607', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/c87dfa5f262fa8ded4078de2ec230661.jpg', 'publishedAt': '2025-05-07T17:05:00Z', 'content': 'In This Story\r\nApple Inc. (AAPL) is exploring how to incorporate AI-powered search engines on its devices and its sending Googles (GOOGL) share price tumbling. \r\nEddy Cue, Apples senior vice presiden… [+2259 chars]'}, {'source': {'id': None, 'name': '9to5Mac'}, 'author': 'Ben Lovejoy', 'title': 'Warren Buffett says Apple made Berkshire more money than he ever did', 'description': 'When Apple CEO Tim Cook praised Warren Buffett at the weekend, it followed the billionaire investor modestly stating that Apple had made more money for his Berkshire Hathaway investment fund than he ever did through his other investment picks.\n\n\n\nBuffett also…', 'url': 'https://9to5mac.com/2025/05/06/warren-buffett-says-apple-made-berkshire-more-money-than-he-ever-did/', 'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2025/05/Warren-Buffett-says-Apple-made-Berkshire-more-money-than-he-ever-did.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1', 'publishedAt': '2025-05-06T12:37:58Z', 'content': 'When Apple CEO Tim Cook praised Warren Buffett at the weekend, it followed the billionaire investor modestly stating that Apple had made more money for his Berkshire Hathaway investment fund than he … [+1476 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Is Apple Inc. (AAPL) the Best Dow Stock?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5bb3a320-0051-47c8-8d00-3e29fded3848', 'urlToImage': None, 'publishedAt': '2025-05-07T18:25:30Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Was Jim Cramer Right About Apple Inc. (AAPL)?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_6eb6a447-b8a1-49e2-ae57-67f558a7f95b', 'urlToImage': None, 'publishedAt': '2025-05-07T20:33:43Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}]}
# 0.30033730158730154
# {'status': 'ok', 'totalResults': 0, 'articles': []}
# {'status': 'ok', 'totalResults': 6, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Larry Ramer', 'title': 'Swiss Bank Remains Bullish on Berkshire (BRK-A, BRK-B) After Buffett Announces Resignation', 'description': 'Swiss bank UBS maintained a Buy rating on Berkshire Hathaway (BRK-A,BRK-B) after its longtime CEO, Warren Buffett, disclosed that he would step down from the...', 'url': 'https://finance.yahoo.com/news/swiss-bank-remains-bullish-berkshire-150035966.html', 'urlToImage': 'https://media.zenfs.com/en/insidermonkey.com/0d55e3042713ac7b07a0f8a16789fe08', 'publishedAt': '2025-05-06T15:00:35Z', 'content': 'Swiss bank UBS maintained a Buy rating on Berkshire Hathaway (BRK-A,BRK-B) after its longtime CEO, Warren Buffett, disclosed that he would step down from the role by the end of this year.\r\nThe bank k… [+1571 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'ChatGPT Stock Advice: Berkshire Hathaway Inc. (BRK-B) Among Top Stock Recommendations', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_976079c2-6f6e-4759-bc0e-a1d6454dc761', 'urlToImage': None, 'publishedAt': '2025-05-06T09:14:04Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': 'Swiss Bank Remains Bullish on Berkshire (BRK-A, BRK-B) After Buffett Announces Resignation', 'description': 'In This Article:\nSwiss bank UBS maintained a Buy rating on Berkshire Hathaway (BRK-A,BRK-B) after its longtime CEO, Warren Buffett, disclosed that he would step down from the role by the end of this year.\nThe bank kept a $606 price target on the shares.\nKrist…', 'url': 'https://biztoc.com/x/f1463464adcdc7bb', 'urlToImage': 'https://biztoc.com/cdn/f1463464adcdc7bb_s.webp', 'publishedAt': '2025-05-06T15:11:35Z', 'content': 'In This Article:Swiss bank UBS maintained a Buy rating on Berkshire Hathaway (BRK-A,BRK-B) after its longtime CEO, Warren Buffett, disclosed that he would step down from the role by the end of this y… [+148 chars]'}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': "Berkshire Hathaway stock steady after 5% drop follows Warren Buffett's succession announcement", 'description': "In This Article:\nBerkshire Hathaway (BRK-A, BRK-B) shares were little-changed on Tuesday, gaining about 0.2% in early trade following a 5% fall in the prior session after the conglomerate's board approved longtime CEO Warren Buffett's successor, vice chair Gr…", 'url': 'https://biztoc.com/x/7071daf307aa0fae', 'urlToImage': 'https://biztoc.com/cdn/7071daf307aa0fae_s.webp', 'publishedAt': '2025-05-06T14:05:00Z', 'content': "In This Article:Berkshire Hathaway (BRK-A, BRK-B) shares were little-changed on Tuesday, gaining about 0.2% in early trade following a 5% fall in the prior session after the conglomerate's board appr… [+148 chars]"}, {'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'finance.yahoo.com', 'title': 'ChatGPT Stock Advice: Berkshire Hathaway Inc. (BRK-B) Among Top Stock Recommendations', 'description': 'We recently published a list of ChatGPT Stock Advice: Top 12 Stock Recommendations. In this article, we will take a look at where Berkshire Hathaway Inc. (NYSE:BRK-B) stands against other top stock recommendations by ChatGPT.\nAfter a two-year surge of 53%, th…', 'url': 'https://biztoc.com/x/bb8e3e25cfc2f621', 'urlToImage': 'https://biztoc.com/cdn/bb8e3e25cfc2f621_s.webp', 'publishedAt': '2025-05-06T09:38:44Z', 'content': 'We recently published a list of ChatGPT Stock Advice: Top 12 Stock Recommendations. In this article, we will take a look at where Berkshire Hathaway Inc. (NYSE:BRK-B) stands against other top stock r… [+151 chars]'}]}
# 0.10611111111111111
# {'status': 'ok', 'totalResults': 53, 'articles': [{'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Niamh Rowe', 'title': 'Apple wants to move to AI-powered search — and Google stock sinks 8%', 'description': 'Apple Inc. (AAPL) is exploring how to incorporate AI-powered search engines on its devices — and it’s sending Google’s (GOOGL) share price tumbling. Read more...', 'url': 'https://qz.com/apple-google-ai-search-engine-lawsuit-alphabet-1851779607', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/c87dfa5f262fa8ded4078de2ec230661.jpg', 'publishedAt': '2025-05-07T17:05:00Z', 'content': 'In This Story\r\nApple Inc. (AAPL) is exploring how to incorporate AI-powered search engines on its devices and its sending Googles (GOOGL) share price tumbling. \r\nEddy Cue, Apples senior vice presiden… [+2259 chars]'}, {'source': {'id': None, 'name': 'Quartz India'}, 'author': 'Catherine Baab', 'title': 'An Apple executive sparked a Google stock selloff. Don’t panic, analyst says', 'description': 'Google (GOOGL) stock slid 7% on Wednesday after Apple’s (AAPL) head of services, Eddy Cue, dropped a bombshell during antitrust testimony: Safari search volume had declined in April for the first time in over two decades.Read more...', 'url': 'https://qz.com/google-stock-apple-ai-search-safari-chrome-analysts-1851779676', 'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/c3e14a70b2bca8c3868f345d9e756c38.jpg', 'publishedAt': '2025-05-08T12:40:00Z', 'content': 'In This Story\r\nGoogle (GOOGL-1.57%\r\n) stock slid 7% on Wednesday after Apples (AAPL-0.39%\r\n) head of services, Eddy Cue, dropped a bombshell during antitrust testimony: Safari search volume had decli… [+2494 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Is Apple Inc. (AAPL) the Best Dow Stock?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5bb3a320-0051-47c8-8d00-3e29fded3848', 'urlToImage': None, 'publishedAt': '2025-05-07T18:25:30Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Was Jim Cramer Right About Apple Inc. (AAPL)?', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_6eb6a447-b8a1-49e2-ae57-67f558a7f95b', 'urlToImage': None, 'publishedAt': '2025-05-07T20:33:43Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': None, 'title': 'Well-Known Investor Cuts His Stakes in NVDA, AVGO, AAPL', 'description': None, 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_853eabec-cac2-431e-9e3d-144eb3774447', 'urlToImage': None, 'publishedAt': '2025-05-07T15:41:34Z', 'content': "If you click 'Accept all', we and our partners, including 241 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"}]}
# 0.37214285714285716
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# {'status': 'error', 'code': 'rateLimited', 'message': 'You have made too many requests recently. Developer accounts are limited to 100 requests over a 24 hour period (50 requests available every 12 hours). Please upgrade to a paid plan if you need more requests.'}
# Price       Open Close
# Ticker      DNUT  DNUT
# Date
# 2025-04-28  4.29  4.19
# 2025-04-29  4.15  4.14
# 2025-04-30  4.06  4.10
# 2025-05-01  4.12  4.22
# 2025-05-02  4.22  4.31
# 2025-05-05  4.30  4.27
# 2025-05-06  4.29  4.36
# 2025-05-07  4.40  4.33
# 2025-05-08  3.03  3.26
# 2025-05-09  3.27  2.73

# %% [markdown]
# ## Step 4:
# Simulate Trading by Backtesting

# %%
# IMport backtesting functionality from python file

from momentum_functions import backtest_sentiment_strategy

# Example usage

results = backtest_sentiment_strategy(sentiment_df, price_dict, init_capital=100000)
results
# Out:
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:45: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(row['Open']), float(row['Close'])
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:36: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   long_tkr   = scores.idxmax()
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:37: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   short_tkr  = scores.idxmin()
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:36: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   long_tkr   = scores.idxmax()
# /Users/celineliew/FINM3422 repositories/FM_momentum/Tutorial/momentum_functions.py:37: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   short_tkr  = scores.idxmin()
#              long  short   open_long  close_long  open_short  close_short  \
# date
# 2025-04-28  BRK-B   AAPL  533.630005  530.940002  210.000000   210.139999
# 2025-04-29  BRK-B   AAPL  531.000000  534.570007  208.690002   211.210007
# 2025-04-30  BRK-B   AAPL  531.510010  533.250000  209.300003   212.500000
# 2025-05-01  BRK-B   AAPL  531.000000  530.229980  209.080002   213.320007
# 2025-05-02  BRK-B   AAPL  536.750000  539.799988  206.089996   205.350006
# 2025-05-03   AAPL  BRK-B         NaN         NaN         NaN          NaN
# 2025-05-04   AAPL   DNUT         NaN         NaN         NaN          NaN
# 2025-05-05   AAPL   DNUT  203.100006  198.889999    4.300000     4.270000
# 2025-05-06   AAPL  BRK-B  198.210007  198.509995  509.570007   512.330017
# 2025-05-07   AAPL   AAPL  199.169998  196.250000  199.169998   196.250000
# 2025-05-08    NaN    NaN         NaN         NaN         NaN          NaN
# 2025-05-09    NaN    NaN         NaN         NaN         NaN          NaN
#
#                pnl_long    pnl_short    daily_pnl  daily_return  \
# date
# 2025-04-28  -252.047525   -33.333188  -285.380713     -0.002854
# 2025-04-29   335.199549  -602.044333  -266.844784     -0.002676
# 2025-04-30   162.779772  -760.230698  -597.450926     -0.006008
# 2025-05-01   -71.672957 -1002.309908 -1073.982865     -0.010865
# 2025-05-02   277.798459   175.538693   453.337152      0.004636
# 2025-05-03     0.000000     0.000000     0.000000      0.000000
# 2025-05-04     0.000000     0.000000     0.000000      0.000000
# 2025-05-05 -1018.088604   342.664048  -675.424556     -0.006876
# 2025-05-06    73.823430  -264.194015  -190.370584     -0.001951
# 2025-05-07  -713.717834   713.717834     0.000000      0.000000
# 2025-05-08     0.000000     0.000000     0.000000      0.000000
# 2025-05-09     0.000000     0.000000     0.000000      0.000000
#
#             portfolio_value
# date
# 2025-04-28     99714.619287
# 2025-04-29     99447.774503
# 2025-04-30     98850.323577
# 2025-05-01     97776.340712
# 2025-05-02     98229.677864
# 2025-05-03     98229.677864
# 2025-05-04     98229.677864
# 2025-05-05     97554.253308
# 2025-05-06     97363.882724
# 2025-05-07     97363.882724
# 2025-05-08     97363.882724
# 2025-05-09     97363.882724

# %% [markdown]
# ## Step 5:
# Display results in ```matplotlib```

# %%
 # Plot the portfolio value

plt.figure(figsize=(10, 5))
plt.plot(results.index, results['portfolio_value'], marker = 'o', linewidth = 2)
plt.title('Sentiment-based strategy: portfolio value over two weeks')
plt.xlabel('Date')
plt.ylabel('Portfolio Value (USD)')
plt.axhline(y=100000, color='r', linestyle='--', label='Initial Capital')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
